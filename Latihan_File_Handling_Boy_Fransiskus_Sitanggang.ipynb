# %% [markdown]
# <a href="https://colab.research.google.com/github/fransB26/MSIB-ORBIT/blob/main/Latihan_File_Handling_Boy_Fransiskus_Sitanggang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def garis():
  print(30*'--')
  print()
garis()
print("NAMA \t: BOY FRANSISKUS SITANGGANG")
print("NIM \t: 4193230018")
print("KELAS \t: ENIGMA\n")
garis()
# Out:
# ------------------------------------------------------------
#
# NAMA 	: BOY FRANSISKUS SITANGGANG
# NIM 	: 4193230018
# KELAS 	: ENIGMA
#
# ------------------------------------------------------------

# %% [markdown]
# **LATIHAN HANDLING AI SOURCE OF POWER**

# %% [markdown]
# ## Latihan 1 (menulis file)
#
# 1. Buat folder baru bernama 'latihan'.
# 2. Buat file baru dalam folder 'latihan' bernama '*my favorite quote.txt*'.
# 3. Write file tersebut dengan kutipan/quote yang sangat kalian sukai.
# 4. Read file yang sudah kalian write.

# %%
latihan1 = open('/content/latihan/my favorite quote.txt','w+')
latihan1.write('~Follow Your Dream~')
latihan1.seek(0)
print(latihan1.read())
latihan1.close()
# Out:
# ~Follow Your Dream~

# %% [markdown]
# ## Latihan 2
#
# 1. Read file CSV dari link ini  https://ngodingdata.com/wp-content/uploads/2020/05/titanic.csv kemudian load dalam DataFrame.
#
# 2. Buat DataFrame baru (DataFrame II) yang hanya berisi kolom 'Survived', 'Pclass', dan 'Age' saja.
#
# 3. Ambil seluruh data dari DataFrame II yang Age > 25, kemudian simpan dalam DataFrame baru (DataFrame III).
#
# 4. Simpan DataFrame III di folder 'latihan' dengan nama 'latihan2.csv'.

# %%
import pandas as pd
DataFrame = pd.read_csv('/content/latihan/titanic.csv')
DataFrame2 = DataFrame[['Survived','Pclass','Age']]
DataFrame3 = DataFrame2[DataFrame2['Age']>25]
DataFrame3
DataFrame3.to_csv('/content/latihan/latihan2.csv')

# %% [markdown]
# ## Latihan 3
#
# 1. Cari image apapun di internet.
# 2. Read dan tampilkan image.
# 3. Cari tahu ukuran tensor-nya.
# 4. Lakukan operasi aritmatika apapun pada image.
# 5. Tampilkan image hasil operasi aritmatika.
# 6. Simpan image hasil operasi aritmatika dalam folder 'latihan' dengan nama 'latihan3.png'

# %%
import cv2
from google.colab.patches import cv2_imshow
img_ai = cv2.imread('/content/latihan/gambar ai.jpg')
cv2_imshow(img_ai)
# Out:
# <PIL.Image.Image image mode=RGB size=360x240 at 0x7FDC69B94650>

# %%
print(img_ai)
# Out:
# [[[118  71  43]
#   [118  71  43]
#   [118  71  43]
#   ...
#   [113  52   2]
#   [114  54   2]
#   [113  53   1]]
#
#  [[119  72  44]
#   [119  72  44]
#   [118  71  43]
#   ...
#   [111  52   2]
#   [111  52   2]
#   [110  52   0]]
#
#  [[119  72  44]
#   [119  72  44]
#   [117  73  44]
#   ...
#   [110  53   2]
#   [108  51   0]
#   [106  49   0]]
#
#  ...
#
#  [[ 39   3   0]
#   [ 38   2   0]
#   [ 36   1   0]
#   ...
#   [ 69  28   5]
#   [ 66  25   3]
#   [ 63  22   0]]
#
#  [[ 52  15   7]
#   [ 51  14   6]
#   [ 48  12   4]
#   ...
#   [ 67  26   1]
#   [ 69  27   4]
#   [ 70  28   5]]
#
#  [[ 59  22  14]
#   [ 60  23  15]
#   [ 58  22  14]
#   ...
#   [ 64  20   0]
#   [ 70  28   5]
#   [ 74  32   9]]]

# %%
print(img_ai.shape)
# Out:
# (240, 360, 3)

# %%
edit_ai = 0.25*(img_ai+10)
cv2_imshow(edit_ai)
# Out:
# <PIL.Image.Image image mode=RGB size=360x240 at 0x7FDC682D6A10>

# %%
cv2.imwrite('/content/latihan/latihan3.png',edit_ai)
# Out:
# True

# %% [markdown]
# ## Latihan 4
#
# 1. Download file dari link berikut https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz kemudian simpan dalam folder 'latihan' dengan nama 'latihan4.tar.gz'
#
# 2. Extract file tersebut kemudan simpan hasil ekstrak di folder 'latihan'.

# %%
# !tar -xjvf '/content/latihan/latihan4.tar.gz'
# Out:
# bzip2: (stdin) is not a bzip2 file.
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now
