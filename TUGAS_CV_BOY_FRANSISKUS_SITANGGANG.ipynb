# %% [markdown]
# <a href="https://colab.research.google.com/github/fransB26/MSIB-ORBIT/blob/main/TUGAS_CV_BOY_FRANSISKUS_SITANGGANG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Desain tanpa judul (2).png](data:image/png;base64,...)

# %% [markdown]
# Pemuda yang ingin menjadi Seorang Data Scientist dan Pengusaha Muda
#
# Nama                  : Boy Fransiskus Sitanggang
#
# Tempat/Tanggal Lahir  : Medan, 26 Maret 2001
#
# Alamat                : JL Tangguk Bongkar VI
#
# Hobi                  : Bermain Laptop dan Hp
#
# Pendidikan            : S-1 Matematika
#
# Pekerjaan             : Mahasiswa
#
# E-mail                : boysitangagng416@gmail.com
#
# Motto                 : Coba aja terus sampe gagal tetapi tetap tidak menyerah
#
# Pengalaman            : - Koordinator IPTEK BMPF
#                         - wakil Ketua Paskah Ikatan Keluarga Besar Kristen Matematika

# %%
print(50*"===")

# %% [markdown]
# ![Desain tanpa judul (2).png](data:image/png;base64,...)

# %%
print("""Pemuda yang ingin menjadi Seorang Data Scientist dan Pengusaha Muda

Nama                  : Boy Fransiskus Sitanggang
Tempat/Tanggal Lahir  : Medan, 26 Maret 2001
Alamat                : JL Tangguk Bongkar VI
Hobi                  : Bermain Laptop dan Hp
Pendidikan            : S-1 Matematika
Pekerjaan             : Mahasiswa
E-mail                : boysitangagng416@gmail.com
Motto                 : Coba aja terus sampe gagal tetapi tetap tidak menyerah
Pengalaman            : - Koordinator IPTEK BMPF
                        - wakil Ketua Paskah Ikatan Keluarga Besar Kristen Matematika
""")
# Out:
# Pemuda yang ingin menjadi Seorang Data Scientist dan Pengusaha Muda
#
# Nama                  : Boy Fransiskus Sitanggang
# Tempat/Tanggal Lahir  : Medan, 26 Maret 2001
# Alamat                : JL Tangguk Bongkar VI
# Hobi                  : Bermain Laptop dan Hp
# Pendidikan            : S-1 Matematika
# Pekerjaan             : Mahasiswa
# E-mail                : boysitangagng416@gmail.com
# Motto                 : Coba aja terus sampe gagal tetapi tetap tidak menyerah
# Pengalaman            : - Koordinator IPTEK BMPF
#                         - wakil Ketua Paskah Ikatan Keluarga Besar Kristen Matematika

# %%
print(50*"===")

# %% [markdown]
# ![Desain tanpa judul (2).png](data:image/png;base64,...)

# %%
print("Pemuda yang ingin menjadi Seorang Data Scientist dan Pengusaha Muda")

print("\nNama\t\t\t: Boy Fransiskus Sitanggang")
print("Tempat/Tanggal Lahir\t: Medan, 26 Maret 2001")
print("Alamat\t\t\t: JL TANGGUK BONGKAR VI")
print("Hobi\t\t\t: Bermain Laptop dan Hp")
print("Pendidikan\t\t: S-1 Matematika")
print("Pekerjaan\t\t: Mahasiswa")
print("E-mail\t\t\t: boysitanggang416@gmail.com")
print("Motto\t\t\t: Coba aja terus sampe gagal tetapi tetap tidak menyerah")
print("Pengalaman\t\t: - Koordinator IPTEK BMPF\n \t\t\t  - Wakil Ketua Paskah Ikatan Keluarga Besar Kristen Matematika")
# Out:
# Pemuda yang ingin menjadi Seorang Data Scientist dan Pengusaha Muda
#
# Nama			: Boy Fransiskus Sitanggang
# Tempat/Tanggal Lahir	: Medan, 26 Maret 2001
# Alamat			: JL TANGGUK BONGKAR VI
# Hobi			: Bermain Laptop dan Hp
# Pendidikan		: S-1 Matematika
# Pekerjaan		: Mahasiswa
# E-mail			: boysitanggang416@gmail.com
# Motto			: Coba aja terus sampe gagal tetapi tetap tidak menyerah
# Pengalaman		: - Koordinator IPTEK BMPF
#  			  - Wakil Ketua Paskah Ikatan Keluarga Besar Kristen Matematika
